# %%
checkpoint_path = '/tmp/delta-gks2/invoices/_checkpoints'

# in the place of gks, use your s3 mount
# where output goes, delta files in parquet format, _delta_logs/*.json
write_path = '/mnt/gks/delta-gks/invoices'

# Input data
upload_path = "s3://trainingmar22-invoices/invoices/"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Set up the stream to begin reading incoming files from the
# upload_path location.
# {"InvoiceNo": 225124, "StockCode": "85123A", "Quantity": 10, 
# "Description": "TODO", "InvoiceDate": "03/25/2022 15:13", 
# "UnitPrice": 2.0, "CustomerID": 12583, "Country": "BE"}

df = spark.readStream.format('cloudFiles') \
  .option('cloudFiles.format', 'json') \
  .option('header', 'true') \
  .schema('InvoiceNo string, StockCode string,  Description string,    InvoiceDate string, UnitPrice double, CustomerID long,  Country string, Quantity long') \
  .load(upload_path)

# .schema('city string, year int, population long') \
# lazy avaluation, will not start stream
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
import pyspark.sql.functions as F
dfWithAmount = df.withColumn("Amount", F.col("UnitPrice") * F.col("Quantity") )
dfWithAmount.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- InvoiceNo: string (nullable = true)
# -- StockCode: string (nullable = true)
# -- Description: string (nullable = true)
# -- InvoiceDate: string (nullable = true)
# -- UnitPrice: double (nullable = true)
# -- CustomerID: long (nullable = true)
# -- Country: long (nullable = true)
# -- Quantity: long (nullable = true)
# -- Amount: double (nullable = true)
#
# </div>

# %%
# Start the stream.
# Use the checkpoint_path location to keep a record of all files that
# have already been uploaded to the upload_path location.
# For those that have been uploaded since the last check,
# write the newly-uploaded files' data to the write_path location.
query = dfWithAmount.writeStream.format('delta') \
  .option('checkpointLocation', checkpoint_path) \
  .start(write_path)

# this starts the query, ACTION on the query
# this will compile using catalyst and execute the plan tongston on phase 1, phase 2....
# by default there will be trigger, trigger as soon as the data is available
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# to check the output in the delta location, this is batch not stream
invoicesDf = spark.read.format('delta').load(write_path)

display(invoicesDf)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>InvoiceNo</th><th>StockCode</th><th>Description</th><th>InvoiceDate</th><th>UnitPrice</th><th>CustomerID</th><th>Country</th><th>Quantity</th><th>Amount</th></tr></thead><tbody><tr><td>927359</td><td>84406G</td><td>TODO</td><td>03/25/2022 15:16</td><td>2.0</td><td>17850</td><td>null</td><td>5</td><td>10.0</td></tr><tr><td>505456</td><td>85123A</td><td>TODO</td><td>03/25/2022 15:13</td><td>1.0</td><td>17850</td><td>null</td><td>10</td><td>10.0</td></tr><tr><td>273724</td><td>84406G</td><td>TODO</td><td>03/25/2022 15:25</td><td>3.0</td><td>12583</td><td>null</td><td>10</td><td>30.0</td></tr><tr><td>152668</td><td>85123A</td><td>TODO</td><td>03/25/2022 15:26</td><td>4.0</td><td>17850</td><td>null</td><td>8</td><td>32.0</td></tr><tr><td>106877</td><td>84406G</td><td>TODO</td><td>03/25/2022 15:18</td><td>4.0</td><td>17850</td><td>null</td><td>2</td><td>8.0</td></tr><tr><td>211129</td><td>84406G</td><td>TODO</td><td>03/25/2022 15:29</td><td>4.0</td><td>13047</td><td>null</td><td>1</td><td>4.0</td></tr><tr><td>111495</td><td>84406B</td><td>TODO</td><td>03/25/2022 15:14</td><td>5.0</td><td>17850</td><td>null</td><td>8</td><td>40.0</td></tr><tr><td>256563</td><td>84406B</td><td>TODO</td><td>03/25/2022 15:23</td><td>1.0</td><td>17850</td><td>null</td><td>5</td><td>5.0</td></tr><tr><td>144778</td><td>85123A</td><td>TODO</td><td>03/25/2022 15:19</td><td>3.0</td><td>13047</td><td>null</td><td>7</td><td>21.0</td></tr><tr><td>261392</td><td>84406B</td><td>TODO</td><td>03/25/2022 15:12</td><td>4.0</td><td>17850</td><td>null</td><td>4</td><td>16.0</td></tr><tr><td>880538</td><td>84406B</td><td>TODO</td><td>03/25/2022 15:17</td><td>4.0</td><td>17850</td><td>null</td><td>3</td><td>12.0</td></tr><tr><td>893342</td><td>71053</td><td>TODO</td><td>03/25/2022 15:22</td><td>4.0</td><td>13047</td><td>null</td><td>7</td><td>28.0</td></tr><tr><td>623203</td><td>84406B</td><td>TODO</td><td>03/25/2022 15:30</td><td>1.0</td><td>13047</td><td>null</td><td>3</td><td>3.0</td></tr><tr><td>378274</td><td>85123A</td><td>TODO</td><td>03/25/2022 15:28</td><td>5.0</td><td>12583</td><td>null</td><td>8</td><td>40.0</td></tr><tr><td>206615</td><td>85123A</td><td>TODO</td><td>03/25/2022 15:27</td><td>2.0</td><td>13047</td><td>null</td><td>9</td><td>18.0</td></tr><tr><td>817511</td><td>84406E</td><td>TODO</td><td>03/25/2022 15:20</td><td>3.0</td><td>12583</td><td>null</td><td>10</td><td>30.0</td></tr><tr><td>102179</td><td>71053</td><td>TODO</td><td>03/25/2022 15:21</td><td>1.0</td><td>17850</td><td>null</td><td>9</td><td>9.0</td></tr><tr><td>186946</td><td>85123A</td><td>TODO</td><td>03/25/2022 15:24</td><td>1.0</td><td>13047</td><td>null</td><td>4</td><td>4.0</td></tr></tbody></table></div>

# %%
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
